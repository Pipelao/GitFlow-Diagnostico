# %%
import json
import pandas as pd
import regex as re

data = [json.loads(line) for line in open('farmers-protest-tweets-2021-03-5.json', 'r')]

# %%
# Flatten data
df_nested_list = pd.json_normalize(data)

# %%
df_nested_list
# Out:
#                                                       url  \
# 0       https://twitter.com/ShashiRajbhar6/status/1376...
# 1       https://twitter.com/kaursuk06272818/status/137...
# 2       https://twitter.com/kaursuk06272818/status/137...
# 3       https://twitter.com/SukhdevSingh_/status/13767...
# 4       https://twitter.com/Davidmu66668113/status/137...
# ...                                                   ...
# 419502  https://twitter.com/TeamSOOUDA/status/13560306...
# 419503  https://twitter.com/VibhaBurman/status/1356030...
# 419504  https://twitter.com/NavJammu/status/1356029858...
# 419505  https://twitter.com/Atwal72/status/13560296726...
# 419506  https://twitter.com/Manjind22050118/status/135...
#
#                              date  \
# 0       2021-03-30T03:33:46+00:00
# 1       2021-03-30T03:33:23+00:00
# 2       2021-03-30T03:31:00+00:00
# 3       2021-03-30T03:30:45+00:00
# 4       2021-03-30T03:30:30+00:00
# ...                           ...
# ...

# %% [markdown]
# ## Pregunta 1

# %% [markdown]
# ### Los top 10 tweets más retweet

# %%
def pregunta_1(df):
    retweet_top = df.sort_values(by=['retweetCount'], ascending=False)
    return retweet_top.head(10)

pregunta_1(df_nested_list)
# Out:
#                                                       url        date  \
# 408128  https://twitter.com/rihanna/status/13566258896...  2021-02-02
# 395142  https://twitter.com/GretaThunberg/status/13566...  2021-02-02
# 266196  https://twitter.com/GretaThunberg/status/13572...  2021-02-04
# 366579  https://twitter.com/miakhalifa/status/13568483...  2021-02-03
# 372793  https://twitter.com/miakhalifa/status/13568277...  2021-02-03
# 314192  https://twitter.com/TeamJuJu/status/1357048037...  2021-02-03
# 215034  https://twitter.com/BobBlackman/status/1357755...  2021-02-05
# 398011  https://twitter.com/vanessa_vash/status/135668...  2021-02-02
# 325261  https://twitter.com/kylekuzma/status/135700972...  2021-02-03
# 163689  https://twitter.com/AmandaCerny/status/1359013...  2021-02-09
#
#                                                   content  \
# 408128  why aren’t we talking about this?! #FarmersPro...
# 395142  We stand in solidarity with the #FarmersProtes...
# ...

# %% [markdown]
# ## Pregunta 2

# %% [markdown]
# ### Los top 10 usuarios en función a la cantidad de tweets que emitieron

# %%
def pregunta_2(df):
    usuarios_top = df['user.username'].value_counts()
    return usuarios_top[:10]

pregunta_2(df_nested_list)
# Out:
# harjot_tweeting    7134
# tasveersandhu      2091
# shells_n_petals    1991
# jot__b             1841
# rebelpacifist      1806
# rumsomal           1722
# Iamjazzie96        1502
# Jass_k_G           1460
# DigitalKisanBot    1453
# z_khalique007      1446
# Name: user.username, dtype: int64

# %% [markdown]
# ## Pregunta 3

# %% [markdown]
# ### Los top 10 días donde hay más tweets

# %%
def pregunta_3(df):
    df_new = df.copy()
    df_new['date'] = df['date'].apply(lambda x: x[:10])
    dias_top = df_new['date'].value_counts()
    return dias_top[:10]

pregunta_3(df_nested_list)
# Out:
# 2021-02-03    83866
# 2021-02-04    58607
# 2021-02-05    33332
# 2021-02-02    28548
# 2021-02-06    22420
# 2021-02-07    11325
# 2021-02-09     9320
# 2021-02-08     8920
# 2021-02-10     7973
# 2021-02-11     5698
# Name: date, dtype: int64

# %% [markdown]
# ## Pregunta 4

# %% [markdown]
# ### Top 10 hashtags más usados

# %%
def pregunta_4(df):
    df_new = df.copy()
    df_new['hashtags'] = df['content'].apply(lambda x: re.findall(r"#(\w+)", x))
    return df_new.explode('hashtags')['hashtags'].value_counts()[:10]

pregunta_4(df_nested_list)
# Out:
# FarmersProtest              406613
# IStandWithFarmers            15783
# farmersprotest               15458
# IndianFarmersHumanRights     12019
# FarmersAreIndia              11043
# StandWithFarmers             10645
# Rihanna                       9117
# FarmersProtests               8750
# Farmers                       6561
# shameonbollywood              6270
# Name: hashtags, dtype: int64

# %%
def Main(df):
    respuesta_1 = pregunta_1(df)
    respuesta_2 = pregunta_2(df)
    respuesta_3 = pregunta_3(df)
    respuesta_4 = pregunta_4(df)
    print("Respuesta a preunta 1: ", respuesta_1)
    print("-------------------------------------")
    print("Respuesta a pregunta 2: ", respuesta_2)
    print("-------------------------------------")
    print("Respuesta a pregunta 3: ", respuesta_3)
    print("-------------------------------------")
    print("Respuesta a pregunta 4: ", respuesta_4)

# %%
Main(df_nested_list)
# Out:
# Respuesta a preunta 1:                                                        url        date  \
# 408128  https://twitter.com/rihanna/status/13566258896...  2021-02-02
# 395142  https://twitter.com/GretaThunberg/status/13566...  2021-02-02
# 266196  https://twitter.com/GretaThunberg/status/13572...  2021-02-04
# 366579  https://twitter.com/miakhalifa/status/13568483...  2021-02-03
# 372793  https://twitter.com/miakhalifa/status/13568277...  2021-02-03
# 314192  https://twitter.com/TeamJuJu/status/1357048037...  2021-02-03
# 215034  https://twitter.com/BobBlackman/status/1357755...  2021-02-05
# 398011  https://twitter.com/vanessa_vash/status/135668...  2021-02-02
# 325261  https://twitter.com/kylekuzma/status/135700972...  2021-02-03
# 163689  https://twitter.com/AmandaCerny/status/1359013...  2021-02-09
#
#                                                   content  \
# 408128  why aren’t we talking about this?! #FarmersPro...
# ...
